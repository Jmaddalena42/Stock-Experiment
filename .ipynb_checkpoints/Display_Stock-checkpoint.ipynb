# %%
import pandas as pd
import numpy as np
import talib as ta

# %%
#import SAM
import Technical
import SAM

# %run SAM.py

# %%
print(weights)
print(weights.shape)
# Out:
# [[0.09001608]
#  [0.08788096]
#  [0.08718989]
#  [0.09553631]
#  [0.08612707]
#  [0.08829303]]
# (6, 1)

# %%
# %run Technical.py

# %%
my_list = map(lambda x: x[0], weights)
ser = pd.Series(my_list)
print(ser)

# df2.tail
# print(test)
# print(predictors)
# Out:
# 0    0.090016
# 1    0.087881
# 2    0.087190
# 3    0.095536
# 4    0.086127
# 5    0.088293
# dtype: float64

# %%
print(train)
# Out:
#                   MA       RSI   Stoch_K   Stoch_D      MACD     WILLR  \
# Date
# 2015-03-20  0.000000  0.500200  0.704475  0.700117  0.401863  0.661517
# 2015-03-23  0.000000  0.423915  0.582883  0.665149  0.438552  0.487097
# 2015-03-24  0.000000  0.376159  0.475451  0.585244  0.430587  0.300000
# 2015-03-25  0.000000  0.258675  0.248220  0.426400  0.415087  0.012722
# 2015-03-26  0.000000  0.256841  0.154791  0.277360  0.402636  0.220338
# 2015-03-27  0.000000  0.288739  0.150636  0.164277  0.394648  0.288136
# 2015-03-30  0.000000  0.440762  0.381533  0.210690  0.398526  0.671983
# 2015-03-31  0.000000  0.350034  0.448228  0.312849  0.394761  0.410767
# 2015-04-01  0.000000  0.305975  0.440895  0.413902  0.388131  0.267198
# 2015-04-02  0.000000  0.330535  0.321473  0.392992  0.384764  0.331006
# 2015-04-06  0.000000  0.391383  0.351153  0.359196  0.386630  0.495512
# 2015-04-07  0.000000  0.438810  0.479655  0.372690  0.391897  0.634098
# ...
